# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://www.newsnow.co.uk/h/Industry+Sectors/Food+&+Drink/Beverages/The+Coca-Cola+Company'

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
news = soup.find('div', class_ = 'hl__inner')

# %%
news.text
# Out:
# 'Beijing Olympics: Coca-Cola quiet on Uyghur genocide after criticizing Georgia election law Fox News16:15China Winter Olympics (Beijing 2022) Food & Drink '

# %%
news1 = soup.find_all('div', class_ = 'hl__inner')

# %%
news1
# Out:
# [<div class="hl__inner"><a class="hll" href="https://c.newsnow.co.uk/A/1114930381?-21841:9025" rel="nofollow" target="_blank">Beijing Olympics: Coca-Cola quiet on Uyghur genocide after criticizing Georgia election law</a> <span class="meta"><span class="src src-part" data-pub="FOXNEWS">Fox News<i class="fas fa-cog"></i></span><span class="time" data-time="1644077745">16:15</span></span><span class="favtags"><a class="fav" href="/h/World+News/Asia/China">China</a> <a class="fav" href="/h/Sport/Olympics/Winter+Olympics">Winter Olympics (Beijing 2022)</a> <a class="fav" href="/h/Industry+Sectors/Food+&amp;+Drink">Food &amp; Drink</a> </span></div>,
# ...

# %%
news1 = [news.text for news in news1]

# %%
news1
# Out:
# ['Beijing Olympics: Coca-Cola quiet on Uyghur genocide after criticizing Georgia election law Fox News16:15China Winter Olympics (Beijing 2022) Food & Drink ',
#  'Winter Olympics puts brands under pressure over rights abuses in China France 2421:04China Winter Olympics (Beijing 2022) Food & Drink ',
#  "Minnesota United's 'LAMPS' Crowned eMLS League Series Two Champion Minnesota United - Official Site15:02Austin FC Minnesota United MLS ",
#  'LAMPS de Mnufc coronado campeón de la eMLS League Series Two Minnesota United - Official Site15:02Austin FC Minnesota United MLS ',
#  'Alpla partners with Coca-Cola Femsa to establish new recycling plant in Mexico FoodBev Media12:45Beverages Mexico Food & Drink ',
#  'Alpla, Coca-Cola FEMSA start construction on new Mexican PET recycling facility NS Packaging11:43Beverages Mexico Food & Drink ',
#  'Molson Coors and Coca-Cola team up to create boozy lemonade drink TMJ402:52Molson Coors Beverages Food & Drink ',
# ...

# %%
news1[0]
# Out:
# 'Beijing Olympics: Coca-Cola quiet on Uyghur genocide after criticizing Georgia election law Fox News16:15China Winter Olympics (Beijing 2022) Food & Drink '

# %%
import pandas as pd

# %%
dataset = pd.DataFrame()

# %%
dataset['News'] = news1

# %%
dataset
# Out:
#                                                   News
# 0    Beijing Olympics: Coca-Cola quiet on Uyghur ge...
# 1    Winter Olympics puts brands under pressure ove...
# 2    Minnesota United's 'LAMPS' Crowned eMLS League...
# 3    LAMPS de Mnufc coronado campeón de la eMLS Lea...
# 4    Alpla partners with Coca-Cola Femsa to establi...
# ..                                                 ...
# 166  The UK and Republic of Ireland have confirmed ...
# 167  Australia will open its borders to all vaccina...
# 168  GCSE and A-level exams will be graded more gen...
# 169  A teenager has admitted killing his younger si...
# 170  Only 15% of the world’s coastal regions remain...
#
# [171 rows x 1 columns]

# %%
dataset.to_excel('News.xlsx')
